# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolalex1612/AI-Training/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import python pandas and declare a data frame

# %%
import pandas as pd

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"])

# %% [markdown]
# Display the datas in the data frame

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# Read a CSV file and create a data frame name "Coffee"

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %% [markdown]
# Display the first 5 rows in the "Coffee" DataFrame

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# Sort the datas in descending order and display the result

# %%
coffee.sort_values("Units Sold" , ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %% [markdown]
# store the parquest file in the "result"  DataFrame

# %%
result = pd.read_parquet("/content/results.parquet")
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %% [markdown]
# Display sample datas from the dataframe

# %%
result.sample(2)
# Out:
#           year    type discipline                         event  \
# 145700  1972.0  Summer  Athletics   Pentathlon, Women (Olympic)
# 139995  1988.0  Summer  Athletics  10,000 metres, Men (Olympic)
#
#                           as  athlete_id  noc  team  place   tied   medal
# 145700      Burglinde Pollak       69716  GDR  None    3.0  False  Bronze
# 139995  Talal Omar Abdillahi       67014  DJI  None   18.0  False    None

# %% [markdown]
# use "loc" to display the required row or column

# %%
result.loc[[0,3],"discipline"]
# Out:
# 0    Tennis
# 3    Tennis
# Name: discipline, dtype: object

# %% [markdown]
# use "iloc" To filter the required row and column

# %%
result.iloc[0:2, [2,3]]
# Out:
#   discipline                   event
# 0     Tennis  Singles, Men (Olympic)
# 1     Tennis  Doubles, Men (Olympic)

# %% [markdown]
# For loop

# %%
for index, row in coffee.iterrows():
  print(index)
  print(row)
  print("\n\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...

# %% [markdown]
# Add price to coffee and calculate the revenue using numpy

# %%
coffee ['Price'] = 100
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25    100
# 1     Monday       Latte          15    100
# 2    Tuesday    Espresso          30    100
# 3    Tuesday       Latte          20    100
# 4  Wednesday    Espresso          35    100

# %%
import numpy as np

coffee['new Price'] = np.where(coffee['Coffee Type'] =='Espresso', 100,140)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  new Price
# 0     Monday    Espresso          25    100        100
# 1     Monday       Latte          15    100        140
# 2    Tuesday    Espresso          30    100        100
# 3    Tuesday       Latte          20    100        140
# 4  Wednesday    Espresso          35    100        100

# %%
coffee.pop('Price')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new Price
# 0     Monday    Espresso          25        100
# 1     Monday       Latte          15        140
# 2    Tuesday    Espresso          30        100
# 3    Tuesday       Latte          20        140
# 4  Wednesday    Espresso          35        100

# %%
coffee['Revenue'] = coffee['new Price'] * coffee['Units Sold']
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new Price  Revenue
# 0     Monday    Espresso          25        100     2500
# 1     Monday       Latte          15        140     2100
# 2    Tuesday    Espresso          30        100     3000
# 3    Tuesday       Latte          20        140     2800
# 4  Wednesday    Espresso          35        100     3500

# %% [markdown]
# Rename new price to price

# %%
coffee = coffee.rename(columns={'new Price':'Price'})
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso          25    100     2500
# 1     Monday       Latte          15    140     2100
# 2    Tuesday    Espresso          30    100     3000
# 3    Tuesday       Latte          20    140     2800
# 4  Wednesday    Espresso          35    100     3500

# %% [markdown]
# Work with bios

# %%
bios = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# copy bios

# %%
bios_new = bios.copy()
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# add new column to change the born_date to datetime fomat

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str.get(0)
bios_new['born_date_time'] = pd.to_datetime(bios_new['born_date'], format="%d-%m-%Y")
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_date_time
# 0  1960-10-02  Jean-François     1886-12-12
# 1         NaN         Arnaud     1969-04-01
# 2  1994-07-17           Jean     1898-08-13
# ...

# %% [markdown]
# Get the information about bios_new

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   athlete_id      145500 non-null  int64
#  1   name            145500 non-null  object
#  2   born_date       143693 non-null  datetime64[ns]
#  3   born_city       110908 non-null  object
#  4   born_region     110908 non-null  object
#  5   born_country    110908 non-null  object
#  6   NOC             145499 non-null  object
#  7   height_cm       106651 non-null  float64
#  8   weight_kg       102070 non-null  float64
#  9   died_date       33940 non-null   object
#  10  first_name      145500 non-null  object
#  11  born_date_time  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), object(7)
# memory usage: 13.3+ MB

# %% [markdown]
# Get only the required datas of the given people

# %%
bios_new.query('first_name == "Carol"')
# Out:
#         athlete_id                      name  born_date  \
# 554            556               Carol Sykes 1941-12-11
# 5350          5369      Carol Menken-Schaudt 1957-11-23
# 5449          5468              Carol Sealey 1959-04-18
# 5504          5525              Carol Turney 1955-06-26
# 11209        11268        Carol Ann Blackman 1947-10-14
# 11327        11387              Carol Lavell 1943-04-08
# 11368        11428             Carol Parsons 1956-02-06
# 26891        27086         Carol Creiniceanu 1939-02-01
# 30689        30925                Carol Bedö 1930-12-13
# 32698        32944             Carol Lindsey 1955-03-26
# 32702        32948             Carol Peterka 1963-12-23
# 35733        36016              Carol Colgan 1960-04-12
# 35741        36024            Carol Eastmore 1952-07-30
# 39303        39608               Carol Vereș 1926-04-12
# 40128        40436               Carol Bower 1956-06-09
# 40132        40440               Carol Brown 1953-04-19
# ...

# %% [markdown]
# Save the csv file

# %%
bios_new.to_csv('./sample_data/bios_new.csv', index = False)

# %% [markdown]
# Group candidates based on their height

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 168 else 'Average' if x < 185 else "Tall")
bios.head(20)
# Out:
#     athlete_id                     name   born_date          born_city  \
# 0            1    Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
# 11          12              Max Decugis  1882-09-24         Paris XVIe
# ...

# %% [markdown]
# Functions in pandas

# %%
def categorise_athlet(row):
  if row['height_cm'] < 168 or row['weight_kg'] < 70:
    return "Light weight"
  elif row['height_cm'] < 185 or row['weight_kg'] <= 85:
    return "Medium weight"
  else:
    return "Heavy weight"

bios['Category'] = bios.apply(categorise_athlet, axis=1)
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       Category
# 0  1960-10-02            Tall   Heavy weight
# 1         NaN         Average  Medium weight
# 2  1994-07-17         Average  Medium weight
# ...

# %% [markdown]
# Merge bios and nocs to display the born country full name

# %%
nocs = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       Category NOC_y  region notes
# 0  1960-10-02            Tall   Heavy weight   FRA  France   NaN
# ...

# %% [markdown]
# rename "region" to "born_country_full"

# %%
bios_new.rename(columns={'region':'born country full'},inplace=True)
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       Category NOC_y born country full notes
# 0  1960-10-02            Tall   Heavy weight   FRA            France   NaN
# ...
